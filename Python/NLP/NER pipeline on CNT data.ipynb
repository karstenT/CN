# %% [markdown]
# developed by Patricia Klinger, modified by Sebastian Gampe

# %%
import pandas as pd
import random
import os
import numpy as np
from cnt.model import DesignEstimator
from cnt.annotate import (annotate, annotate_single_design, 
                          annotate_designs, 
                          extract_string_from_annotation)
from cnt.io import (load_entities_from_file, load_entities_from_db, 
                    load_designs, replace_left_right)
from cnt.train_test import train_test_annotate
from cnt.extract_relation import path
from cnt.evaluate import score_precision_recall, score_accuracy
from spacy import displacy

# %%
# load designs from CNT database
english_designs = load_designs()
english_designs.head()
# Out:
# /home/cnt/anaconda3/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py:1569: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   cursor.execute('SELECT @@tx_isolation')
#    DesignID                                          DesignEng
# 0         1  Diademed head of deified Alexander the Great w...
# 1         2  Diademed head of deified Alexander the Great w...
# 2         3           Altar entwined by serpent, head to left.
# 3         4          Altar entwined by serpent, head to right.
# 4         5                      Altar on two levels, flaming.

# %%
# create dictionary entities: key = label, value = entities
mysql_connection = "mysql://cnt:rJnW6m7kZR@localhost:3306/thrakien_cnt"
entities = {
    "PERSON": load_entities_from_db("nlp_list_person", mysql_connection),
    "OBJECT": load_entities_from_db("nlp_list_obj", mysql_connection),
    "ANIMAL": load_entities_from_db("nlp_list_animal", mysql_connection),
    "PLANT": load_entities_from_db("nlp_list_plant", mysql_connection)
}
entities["PERSON"][:3]
# Out:
# /home/cnt/anaconda3/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py:1569: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   cursor.execute('SELECT @@tx_isolation')
# ['Agrippina minor', 'Agrippina maior', 'Alexander III']

# %%
annotated_designs = annotate_designs(entities, english_designs)
annotated_designs = annotated_designs[
    annotated_designs.annotations.map(len) > 0]
annotated_designs.head()
# Out:
#                                            DesignEng  DesignID  \
# 0  Diademed head of deified Alexander the Great w...         1
# 1  Diademed head of deified Alexander the Great w...         2
# 2           Altar entwined by serpent, head to left.         3
# 3          Altar entwined by serpent, head to right.         4
# 4                      Altar on two levels, flaming.         5
#
#                                          annotations
# 0                                 [(25, 44, PERSON)]
# 1                                 [(25, 44, PERSON)]
# 2  [(0, 5, PERSON), (0, 5, OBJECT), (18, 25, ANIM...
# 3  [(0, 5, PERSON), (0, 5, OBJECT), (18, 25, ANIM...
# 4                   [(0, 5, PERSON), (0, 5, OBJECT)]

# %%
#extract entities from designs for train/test split
extract_entities_from_designs = annotated_designs.apply(
    lambda x: extract_string_from_annotation(x.annotations, x.DesignEng), axis=1)
extract_entities_from_designs.head()
# Out:
# 0      [Alexander the Great]
# 1      [Alexander the Great]
# 2    [Altar, Altar, serpent]
# 3    [Altar, Altar, serpent]
# 4             [Altar, Altar]
# dtype: object

# %%
# sklearn train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(annotated_designs[["DesignID", "DesignEng"]],
                                                    annotated_designs[["DesignID", "annotations"]], 
                                                    test_size=0.25)

# %%
# train estimator
n_rep = 3
my_estimator = DesignEstimator(n_rep)
my_estimator.fit(X_train, y_train.annotations)

# %%
train_score = score_accuracy(y_train.rename(columns = {"annotations" : "y"}), my_estimator.predict(X_train))
test_score = score_accuracy(y_test.rename(columns = {"annotations" : "y"}), my_estimator.predict(X_test))
res = {"n_rep": n_rep, "train_score": train_score,
       "test_score": test_score}

# %%
res
# Out:
# {'n_rep': 3,
#  'test_score': 0.7899408284023669,
#  'train_score': 0.8545574202040145}

# %%
precision, recall = score_precision_recall(y_test.rename(columns = {"annotations" : "y"}), my_estimator.predict(X_test))
res.update({"precision":precision, "recall":recall, "split": "random"})

# %%
precision
# Out:
# 0.9818431911966987

# %%
recall
# Out:
# 0.9451800847457628

# %%
y_pred = my_estimator.predict(X_test)
y_pred_predictions_only = y_pred["y"]
y_pred_as_doc = my_estimator.predict(X_test, as_doc=True)
y_pred_as_doc_predictions_only = y_pred_as_doc["y"]

# %%
prediction_output = pd.DataFrame({"X_test" : X_test["DesignEng"], 
                                  "y_test" : y_test["annotations"],
                                  "y_predict" : y_pred_predictions_only,
                                  "y_predict_as_doc" : 
                                      y_pred_as_doc_predictions_only})
prediction_output.head()
# Out:
#                                                  X_test  \
# 186   Athena standing in biga to right, holding rein...
# 2955                     Veiled bust of Demeter, right.
# 1319  To left city goddess standing right, wearing k...
# 2086  Helmet from front surmounted by starand with a...
# 628            Head of Helios facing, slightly to left.
#
#                                               y_predict  \
# 186   [(0, 6, PERSON), (19, 23, OBJECT), (42, 47, OB...
# 2955                [(7, 11, OBJECT), (15, 22, PERSON)]
# 1319  [(8, 20, PERSON), (45, 53, OBJECT), (90, 97, P...
# 2086                                   [(0, 6, OBJECT)]
# 628                                   [(8, 14, PERSON)]
#
#                                        y_predict_as_doc  \
# 186   (Athena, standing, in, biga, to, right, ,, hol...
# 2955           (Veiled, bust, of, Demeter, ,, right, .)
# 1319  (To, left, city, goddess, standing, right, ,, ...
# 2086  (Helmet, from, front, surmounted, by, starand,...
# 628   (Head, of, Helios, facing, ,, slightly, to, le...
#
#                                                  y_test
# 186   [(0, 6, PERSON), (19, 23, OBJECT), (42, 47, OB...
# 2955                [(7, 11, OBJECT), (15, 22, PERSON)]
# 1319  [(8, 20, PERSON), (45, 53, OBJECT), (90, 97, P...
# 2086                                   [(0, 6, OBJECT)]
# 628                                   [(8, 14, PERSON)]

# %%
len(prediction_output)
# Out:
# 1014

# %%
correct_predictions = prediction_output[
    prediction_output.y_predict
    == prediction_output.y_test]
correct_predictions.head()
# Out:
#                                                  X_test  \
# 186   Athena standing in biga to right, holding rein...
# 2955                     Veiled bust of Demeter, right.
# 1319  To left city goddess standing right, wearing k...
# 2086  Helmet from front surmounted by starand with a...
# 628            Head of Helios facing, slightly to left.
#
#                                               y_predict  \
# 186   [(0, 6, PERSON), (19, 23, OBJECT), (42, 47, OB...
# 2955                [(7, 11, OBJECT), (15, 22, PERSON)]
# 1319  [(8, 20, PERSON), (45, 53, OBJECT), (90, 97, P...
# 2086                                   [(0, 6, OBJECT)]
# 628                                   [(8, 14, PERSON)]
#
#                                        y_predict_as_doc  \
# 186   (Athena, standing, in, biga, to, right, ,, hol...
# 2955           (Veiled, bust, of, Demeter, ,, right, .)
# 1319  (To, left, city, goddess, standing, right, ,, ...
# 2086  (Helmet, from, front, surmounted, by, starand,...
# 628   (Head, of, Helios, facing, ,, slightly, to, le...
#
#                                                  y_test
# 186   [(0, 6, PERSON), (19, 23, OBJECT), (42, 47, OB...
# 2955                [(7, 11, OBJECT), (15, 22, PERSON)]
# 1319  [(8, 20, PERSON), (45, 53, OBJECT), (90, 97, P...
# 2086                                   [(0, 6, OBJECT)]
# 628                                   [(8, 14, PERSON)]

# %%
len(correct_predictions)
# Out:
# 801

# %%
wrong_predictions = prediction_output[
    prediction_output.y_predict
    != prediction_output.y_test]
wrong_predictions.head()
# Out:
#                                                  X_test  \
# 2110  Nude, bearded Heracles standing facing, head t...
# 2696  Athena standing left, wearing helmet and long ...
# 3645  Apis-bull advancing right; a disc between the ...
# 506   Galley to right with six rowers; on stern, hel...
# 1805  Nude Apollo standing facing, head to left, cro...
#
#                                               y_predict  \
# 2110  [(14, 22, PERSON), (63, 67, OBJECT), (83, 87, ...
# 2696  [(0, 6, PERSON), (30, 36, OBJECT), (46, 52, OB...
# 3645  [(0, 9, PERSON), (29, 33, OBJECT), (59, 65, OB...
# 506   [(0, 6, OBJECT), (36, 41, OBJECT), (57, 62, OB...
# 1805  [(5, 11, PERSON), (79, 83, OBJECT), (99, 105, ...
#
#                                        y_predict_as_doc  \
# 2110  (Nude, ,, bearded, Heracles, standing, facing,...
# 2696  (Athena, standing, left, ,, wearing, helmet, a...
# 3645  (Apis, -, bull, advancing, right, ;, a, disc, ...
# 506   (Galley, to, right, with, six, rowers, ;, on, ...
# 1805  (Nude, Apollo, standing, facing, ,, head, to, ...
#
#                                                  y_test
# 2110  [(14, 22, PERSON), (63, 67, OBJECT), (83, 92, ...
# 2696  [(0, 6, PERSON), (30, 36, OBJECT), (46, 52, OB...
# 3645  [(0, 4, PERSON), (0, 9, ANIMAL), (29, 33, OBJE...
# 506   [(0, 6, OBJECT), (36, 41, OBJECT), (71, 80, OB...
# 1805  [(5, 11, PERSON), (79, 83, OBJECT), (99, 105, ...

# %%
len(wrong_predictions)
# Out:
# 213

# %%
colors = {'OBJECT': '#99FF33', 'ANIMAL' : '#FFFF33'}
options = {'ent': ['OBJECT', 'ANIMAL'], 'colors': colors}
displacy.render(correct_predictions.y_predict_as_doc, 
                style='ent', jupyter=True, options=options)
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Athena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  standing in
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     biga
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  to right, holding
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     reins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  in right hand,
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     shield
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  and
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     spear
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  in left hand.</div>
#
# <div class="entities" style="line-height: 2.5">Veiled
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     bust
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Demeter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , right.</div>
#
# <div class="entities" style="line-height: 2.5">To left
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     city goddess
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  standing right, wearing
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     kalathos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
# , clasping right hands with laureate
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     emperor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to right standing left, wearing
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     cuirass
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  and
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     boots
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Helmet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  from front surmounted by starand with a feather on each side and cheek-guards. Border of dots.</div>
#
# <div class="entities" style="line-height: 2.5">Head of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Helios
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  facing, slightly to left.</div>
#
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Artemis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (Tauropolos) advancing right, holding a
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     torch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  in each hand.</div>
#
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #FFFF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Owl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANIMAL</span>
# </mark>
#  standing facing; tongs of Hephaistos to left.</div>
#
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Vine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PLANT</span>
# </mark>
#  with six bunches of
# <mark class="ent

# %%
displacy.render(wrong_predictions.y_predict_as_doc, 
                style='ent', jupyter=True, options=options)
# Out:
# <div class="entities" style="line-height: 2.5">Nude, bearded
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Heracles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  standing facing, head to right, holding
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     club
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  in right hand,
# <mark class="entity" style="background: #FFFF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     lion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANIMAL</span>
# </mark>
# -skin over left arm and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     apples
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PLANT</span>
# </mark>
#  of the Hesperides in left hand. Border of dots.</div>
#
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Athena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  standing left, wearing
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     helmet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  and long
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     chiton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
# , holding
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     laurel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PLANT</span>
# </mark>
# -
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     branch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PLANT</span>
# </mark>
#  in right hand,
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     spear
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  and
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     shield
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  in left hand. Ground line. Border of dots.</div>
#
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Apis-bull
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  advancing right; a
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     disc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  between the horns and an
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     uraeus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  inside of it.</div>
#
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Galley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  to right with six rowers; on
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     stern
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
# , helmsman in a
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     cabin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  and two
# <mark class="entity" style="background: #99FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     standards
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5">Nude
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Apollo
#     <span style="font-size: 0.8em; font-weight: bold; l

# %%
# load designs again from CNT database and use the trained model on them
cnt_designs = load_designs()
cnt_designs.head()

cnt_pred = my_estimator.predict_clear(cnt_designs)

cnt_pred_predictions_only = cnt_pred["y"]


#prediction_output = pd.DataFrame({"X_test" : cnt_designs["DesignEng"], 
                                 # "y_test" : cnt_pred["annotations"]})
#prediction_output.head()
# Out:
# /home/cnt/anaconda3/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py:1569: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   cursor.execute('SELECT @@tx_isolation')

# %%
cnt_designs.head()
# Out:
#    DesignID                                          DesignEng
# 0         1  Diademed head of deified Alexander the Great w...
# 1         2  Diademed head of deified Alexander the Great w...
# 2         3           Altar entwined by serpent, head to left.
# 3         4          Altar entwined by serpent, head to right.
# 4         5                      Altar on two levels, flaming.

# %%
cnt_pred_predictions_only = cnt_pred["y"]
cnt_prediction_output = pd.DataFrame({"DesignID" : cnt_designs["DesignID"],
                                      "X_test" : cnt_designs["DesignEng"], 
                                  "y_predict" : cnt_pred_predictions_only})
cnt_prediction_output.head()
#cnt_prediction_output["y_predict"]
# Out:
#    DesignID                                             X_test  \
# 0         1  Diademed head of deified Alexander the Great w...
# 1         2  Diademed head of deified Alexander the Great w...
# 2         3           Altar entwined by serpent, head to left.
# 3         4          Altar entwined by serpent, head to right.
# 4         5                      Altar on two levels, flaming.
#
#                                            y_predict
# 0                    [(Alexander the Great, PERSON)]
# 1  [(Alexander the Great, PERSON), (truncation, O...
# 2               [(Altar, OBJECT), (serpent, ANIMAL)]
# 3               [(Altar, OBJECT), (serpent, ANIMAL)]
# 4                                  [(Altar, OBJECT)]

# %%
cnt_ner_output = pd.DataFrame([(str(designid), *relation) for  _, (designid, relation_list) in cnt_pred.iterrows()
                    for relation in relation_list],
            columns=["DesignID", "Entity", "Label_Entity"])

cnt_ner_output.to_sql("cnt_pipeline_ner", 
                           "mysql://cnt:rJnW6m7kZR@localhost:3306/thrakien_cnt", 
                           if_exists="replace", index=False)
# Out:
# /home/cnt/anaconda3/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py:1569: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   cursor.execute('SELECT @@tx_isolation')
